# %% [markdown]
# ![image.png](attachment:51a62ff6-dd19-4e0a-8fc2-637d280535da.png)

# %%
list_values = [1,2,3,4,5,6,7,8,9]

even_numbers = [ i for i in list_values if i%2==0]
even_num_filter = list(filter(lambda x:x%2==0,list_values))

def my_filter(num_list_values):
    """filter out evene numbers"""
    result_list = []
    for i in num_list_values:
        if i%2==0:
            result_list.append(i)
    print(result_list)
            
    
print(even_numbers)
print(even_num_filter)
my_filter(list_values)
# Out:
# [2, 4, 6, 8]
# [2, 4, 6, 8]
# [2, 4, 6, 8]

# %%
Suceess = Laerning (Running ,  Shallow , Skip(Hard,Not digistice,convient ,stop at teacher) +  Repetation / Revisison (Some lost - Uncomfotable -Skipping- Accpet -do more rep) +  Reproduce - Writng(Paper) (unable proce -  ego -ignored) + Human (Story -Convice - Pysology - Present -  conneting) + System(Reproduce) (Sytax -logic-time -  explanatianity -comments)

# %%
students_list_of_lists = [
    ["name", "marks", "grade", "class", "section"],
    ["Aarav Sharma",  88, "A",  10, "A"],
    ["Diya Patel",    92, "A+", 10, "B"],
    ["Vivaan Reddy",  75, "B",  9,  "A"],
    ["Ananya Iyer",   81, "A",  9,  "C"],
    ["Aditya Nair",   67, "C",  8,  "B"],
    ["Ishaan Gupta",  95, "A+", 10, "A"],
    ["Saanvi Rao",    58, "D",  8,  "A"],
    ["Kabir Menon",   73, "B",  9,  "B"],
    ["Myra Joshi",    84, "A",  10, "C"],
    ["Reyansh Verma", 62, "C",  8,  "C"],
    ["Aadhya Singh",  90, "A+", 9,  "A"],
    ["Arjun Kumar",   78, "B",  10, "B"],
    ["Kiara Das",     55, "D",  8,  "B"],
    ["Vihaan Bose",   69, "C",  9,  "C"],
    ["Anika Kapoor",  87, "A",  10, "A"],
]

# %%
students_list_of_tuples = [
    ("name", "marks", "grade", "class", "section"),
    ("Aarav Sharma",  88, "A",  10, "A"),
    ("Diya Patel",    92, "A+", 10, "B"),
    ("Vivaan Reddy",  75, "B",  9,  "A"),
    ("Ananya Iyer",   81, "A",  9,  "C"),
    ("Aditya Nair",   67, "C",  8,  "B"),
    ("Ishaan Gupta",  95, "A+", 10, "A"),
    ("Saanvi Rao",    58, "D",  8,  "A"),
    ("Kabir Menon",   73, "B",  9,  "B"),
    ("Myra Joshi",    84, "A",  10, "C"),
    ("Reyansh Verma", 62, "C",  8,  "C"),
    ("Aadhya Singh",  90, "A+", 9,  "A"),
    ("Arjun Kumar",   78, "B",  10, "B"),
    ("Kiara Das",     55, "D",  8,  "B"),
    ("Vihaan Bose",   69, "C",  9,  "C"),
    ("Anika Kapoor",  87, "A",  10, "A"),
]

# %%
students_list_of_dicts = [
    {"name": "Aarav Sharma",  "marks": 88, "grade": "A",  "class": 10, "section": "A"},
    {"name": "Diya Patel",    "marks": 92, "grade": "A+", "class": 10, "section": "B"},
    {"name": "Vivaan Reddy",  "marks": 75, "grade": "B",  "class": 9,  "section": "A"},
    {"name": "Ananya Iyer",   "marks": 81, "grade": "A",  "class": 9,  "section": "C"},
    {"name": "Aditya Nair",   "marks": 67, "grade": "C",  "class": 8,  "section": "B"},
    {"name": "Ishaan Gupta",  "marks": 95, "grade": "A+", "class": 10, "section": "A"},
    {"name": "Saanvi Rao",    "marks": 58, "grade": "D",  "class": 8,  "section": "A"},
    {"name": "Kabir Menon",   "marks": 73, "grade": "B",  "class": 9,  "section": "B"},
    {"name": "Myra Joshi",    "marks": 84, "grade": "A",  "class": 10, "section": "C"},
    {"name": "Reyansh Verma", "marks": 62, "grade": "C",  "class": 8,  "section": "C"},
    {"name": "Aadhya Singh",  "marks": 90, "grade": "A+", "class": 9,  "section": "A"},
    {"name": "Arjun Kumar",   "marks": 78, "grade": "B",  "class": 10, "section": "B"},
    {"name": "Kiara Das",     "marks": 55, "grade": "D",  "class": 8,  "section": "B"},
    {"name": "Vihaan Bose",   "marks": 69, "grade": "C",  "class": 9,  "section": "C"},
    {"name": "Anika Kapoor",  "marks": 87, "grade": "A",  "class": 10, "section": "A"},
]

# %%
students_dict_of_lists = {
    "name": [
        "Aarav Sharma", "Diya Patel", "Vivaan Reddy", "Ananya Iyer", "Aditya Nair",
        "Ishaan Gupta", "Saanvi Rao", "Kabir Menon", "Myra Joshi", "Reyansh Verma",
        "Aadhya Singh", "Arjun Kumar", "Kiara Das", "Vihaan Bose", "Anika Kapoor",
    ],
    "marks": [88, 92, 75, 81, 67, 95, 58, 73, 84, 62, 90, 78, 55, 69, 87],
    "grade": ["A", "A+", "B", "A", "C", "A+", "D", "B", "A", "C", "A+", "B", "D", "C", "A"],
    "class": [10, 10, 9, 9, 8, 10, 8, 9, 10, 8, 9, 10, 8, 9, 10],
    "section": ["A", "B", "A", "C", "B", "A", "A", "B", "C", "C", "A", "B", "B", "C", "A"],
}

# %%
students_dict = {
    "S01": {"name": "Aarav Sharma",  "marks": 88, "grade": "A",  "class": 10, "section": "A"},
    "S02": {"name": "Diya Patel",    "marks": 92, "grade": "A+", "class": 10, "section": "B"},
    "S03": {"name": "Vivaan Reddy",  "marks": 75, "grade": "B",  "class": 9,  "section": "A"},
    "S04": {"name": "Ananya Iyer",   "marks": 81, "grade": "A",  "class": 9,  "section": "C"},
    "S05": {"name": "Aditya Nair",   "marks": 67, "grade": "C",  "class": 8,  "section": "B"},
    "S06": {"name": "Ishaan Gupta",  "marks": 95, "grade": "A+", "class": 10, "section": "A"},
    "S07": {"name": "Saanvi Rao",    "marks": 58, "grade": "D",  "class": 8,  "section": "A"},
    "S08": {"name": "Kabir Menon",   "marks": 73, "grade": "B",  "class": 9,  "section": "B"},
    "S09": {"name": "Myra Joshi",    "marks": 84, "grade": "A",  "class": 10, "section": "C"},
    "S10": {"name": "Reyansh Verma", "marks": 62, "grade": "C",  "class": 8,  "section": "C"},
    "S11": {"name": "Aadhya Singh",  "marks": 90, "grade": "A+", "class": 9,  "section": "A"},
    "S12": {"name": "Arjun Kumar",   "marks": 78, "grade": "B",  "class": 10, "section": "B"},
    "S13": {"name": "Kiara Das",     "marks": 55, "grade": "D",  "class": 8,  "section": "B"},
    "S14": {"name": "Vihaan Bose",   "marks": 69, "grade": "C",  "class": 9,  "section": "C"},
    "S15": {"name": "Anika Kapoor",  "marks": 87, "grade": "A",  "class": 10, "section": "A"},
}

# %%
students_list_of_lists = [
    ["name", "marks", "grade", "class", "section"],
    ["Aarav Sharma",  88, "A",  10, "A"],
    ["Diya Patel",    92, "A+", 10, "B"],
    ["Vivaan Reddy",  75, "B",  9,  "A"],
    ["Ananya Iyer",   81, "A",  9,  "C"],
    ["Aditya Nair",   67, "C",  8,  "B"],
    ["Ishaan Gupta",  95, "A+", 10, "A"],
    ["Saanvi Rao",    58, "D",  8,  "A"],
    ["Kabir Menon",   73, "B",  9,  "B"],
    ["Myra Joshi",    84, "A",  10, "C"],
    ["Reyansh Verma", 62, "C",  8,  "C"],
    ["Aadhya Singh",  90, "A+", 9,  "A"],
    ["Arjun Kumar",   78, "B",  10, "B"],
    ["Kiara Das",     55, "D",  8,  "B"],
    ["Vihaan Bose",   69, "C",  9,  "C"],
    ["Anika Kapoor",  87, "A",  10, "A"],
]
TOP_GRADES = ("A", "A+")
header = students_list_of_lists[0]
# grade is at index 2 in each row.
# filter() + lambda keeps only rows whose grade is a top grade.
filtered = list(filter(lambda row: row[2] in TOP_GRADES, students_list_of_lists[1:]))

def my_filter(students_list_of_list):
    result_list_list=[]
    header = students_list_of_list[0]
    for row in students_list_of_list[1:]:
        if row[2] in TOP_GRADES:
            result_list_list.append(row)
    for row in result_list_list:
        print(row)
        
my_filter(students_list_of_lists)        

print("==============")
result_list_lists = [ row for row in students_list_of_lists[1:] if row[2] in TOP_GRADES]
for row in result_list_lists:
    print(row)
# Out:
# ['Aarav Sharma', 88, 'A', 10, 'A']
# ['Diya Patel', 92, 'A+', 10, 'B']
# ['Ananya Iyer', 81, 'A', 9, 'C']
# ['Ishaan Gupta', 95, 'A+', 10, 'A']
# ['Myra Joshi', 84, 'A', 10, 'C']
# ['Aadhya Singh', 90, 'A+', 9, 'A']
# ['Anika Kapoor', 87, 'A', 10, 'A']
# ==============
# ['Aarav Sharma', 88, 'A', 10, 'A']
# ['Diya Patel', 92, 'A+', 10, 'B']
# ['Ananya Iyer', 81, 'A', 9, 'C']
# ['Ishaan Gupta', 95, 'A+', 10, 'A']
# ['Myra Joshi', 84, 'A', 10, 'C']
# ['Aadhya Singh', 90, 'A+', 9, 'A']
# ['Anika Kapoor', 87, 'A', 10, 'A']

# %%
for row in filtered:
    print(row)
# Out:
# ['Aarav Sharma', 88, 'A', 10, 'A']
# ['Diya Patel', 92, 'A+', 10, 'B']
# ['Ananya Iyer', 81, 'A', 9, 'C']
# ['Ishaan Gupta', 95, 'A+', 10, 'A']
# ['Myra Joshi', 84, 'A', 10, 'C']
# ['Aadhya Singh', 90, 'A+', 9, 'A']
# ['Anika Kapoor', 87, 'A', 10, 'A']

# %%
TOP_GRADES = ("A", "A+")
header = students_list_of_tuples[0]
filtered = list(filter(lambda row: row[2] in TOP_GRADES, students_list_of_tuples[1:]))
for row in filtered:
    print(row)
# Out:
# ('Aarav Sharma', 88, 'A', 10, 'A')
# ('Diya Patel', 92, 'A+', 10, 'B')
# ('Ananya Iyer', 81, 'A', 9, 'C')
# ('Ishaan Gupta', 95, 'A+', 10, 'A')
# ('Myra Joshi', 84, 'A', 10, 'C')
# ('Aadhya Singh', 90, 'A+', 9, 'A')
# ('Anika Kapoor', 87, 'A', 10, 'A')

# %%
filtered = list(filter(lambda info: info["grade"] in TOP_GRADES, students_list_of_dicts))
for row in filtered:
    print(row)
# Out:
# {'name': 'Aarav Sharma', 'marks': 88, 'grade': 'A', 'class': 10, 'section': 'A'}
# {'name': 'Diya Patel', 'marks': 92, 'grade': 'A+', 'class': 10, 'section': 'B'}
# {'name': 'Ananya Iyer', 'marks': 81, 'grade': 'A', 'class': 9, 'section': 'C'}
# {'name': 'Ishaan Gupta', 'marks': 95, 'grade': 'A+', 'class': 10, 'section': 'A'}
# {'name': 'Myra Joshi', 'marks': 84, 'grade': 'A', 'class': 10, 'section': 'C'}
# {'name': 'Aadhya Singh', 'marks': 90, 'grade': 'A+', 'class': 9, 'section': 'A'}
# {'name': 'Anika Kapoor', 'marks': 87, 'grade': 'A', 'class': 10, 'section': 'A'}

# %%
filtered = dict(filter(lambda item: item[1]["grade"] in TOP_GRADES, students_dict.items()))
for row in filtered:
    print(row,students_dict[row])
# Out:
# S01 {'name': 'Aarav Sharma', 'marks': 88, 'grade': 'A', 'class': 10, 'section': 'A'}
# S02 {'name': 'Diya Patel', 'marks': 92, 'grade': 'A+', 'class': 10, 'section': 'B'}
# S04 {'name': 'Ananya Iyer', 'marks': 81, 'grade': 'A', 'class': 9, 'section': 'C'}
# S06 {'name': 'Ishaan Gupta', 'marks': 95, 'grade': 'A+', 'class': 10, 'section': 'A'}
# S09 {'name': 'Myra Joshi', 'marks': 84, 'grade': 'A', 'class': 10, 'section': 'C'}
# S11 {'name': 'Aadhya Singh', 'marks': 90, 'grade': 'A+', 'class': 9, 'section': 'A'}
# S15 {'name': 'Anika Kapoor', 'marks': 87, 'grade': 'A', 'class': 10, 'section': 'A'}

# %%
keep = list(filter(lambda i: students_dict_of_lists["grade"][i] in TOP_GRADES, range(len(students_dict_of_lists["grade"]))))
filtered = {col: [values[i] for i in keep] for col, values in students_dict_of_lists.items()}
for row in filtered:
    print(row)
# Out:
# name
# marks
# grade
# class
# section

# %%
restaurant_to_styles = {
    "Spice Villa":      ["Indian", "Chinese"],
    "Pasta House":      ["Italian"],
    "Dragon Wok":       ["Chinese", "Japanese"],
    "Curry Leaf":       ["Indian"],
    "Sushi Zen":        ["Japanese"],
    "Bella Napoli":     ["Italian", "Mexican"],
    "Taco Fiesta":      ["Mexican"],
    "Golden Panda":     ["Chinese"],
    "Tandoori Nights":  ["Indian", "Italian"],
    "Ramen Bar":        ["Japanese", "Chinese"],
    "El Sombrero":      ["Mexican", "Indian"],
    "Olive Garden Co":  ["Italian"],
}

# %%
reversed_map = {}
for restaurant, styles in restaurant_to_styles.items():
    # Each restaurant has a LIST of styles; loop over each style.
    for style in styles:
        # If we have not seen this style yet, start a new empty list.
        if style not in reversed_map:
            reversed_map[style] = []
        # Add this restaurant under the style.
        reversed_map[style].append(restaurant)
print(reversed_map)
# Out:
# {'Indian': ['Spice Villa', 'Curry Leaf', 'Tandoori Nights', 'El Sombrero'], 'Chinese': ['Spice Villa', 'Dragon Wok', 'Golden Panda', 'Ramen Bar'], 'Italian': ['Pasta House', 'Bella Napoli', 'Tandoori Nights', 'Olive Garden Co'], 'Japanese': ['Dragon Wok', 'Sushi Zen', 'Ramen Bar'], 'Mexican': ['Bella Napoli', 'Taco Fiesta', 'El Sombrero']}
